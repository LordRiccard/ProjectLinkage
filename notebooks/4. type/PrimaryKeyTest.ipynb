# %%
import pandas as pd
import glob

# %%
def find_files(path, pattern, i):
    files = glob.glob(f'{path}/{pattern}')
    # print(files)
    # print(len(files))

    return files

# %%
for i in range(12, 23):
    files = find_files('D:\\_repositories\\Aggregation\\Results\\SINASC - Dtype Corrigido\\parquet', f'*20{i}.parquet')

    df = pd.read_parquet(files[0])
    print(f'Ano: 20{i} - Quantidade de registros: {len(df)}')
# Out:
# Ano: 2012 - Quantidade de registros: 3197707
# Ano: 2013 - Quantidade de registros: 3197575
# Ano: 2014 - Quantidade de registros: 3282309
# Ano: 2015 - Quantidade de registros: 3311296
# Ano: 2016 - Quantidade de registros: 3149750
# Ano: 2017 - Quantidade de registros: 3216411
# Ano: 2018 - Quantidade de registros: 3232183
# Ano: 2019 - Quantidade de registros: 3139558
# Ano: 2020 - Quantidade de registros: 3013130
# Ano: 2021 - Quantidade de registros: 2951464
# Ano: 2022 - Quantidade de registros: 2856466

# %%
df = pd.read_csv('D:\\_repositories\\Aggregation\\Results\\SIH - Concatenado\\RD2022.csv', usecols=['UF_ZI'])
print(len(df))
# Out:
# 7738647

# %%
df = pd.read_csv('D:\\_repositories\\Aggregation\\SIM-2DtypeCorrigido\\csv\\SIM2022.csv')
print(len(df))
# Out:
# 58791

# %% [markdown]
# ---

# %%
df = pd.read_parquet('D:\\_repositories\\Aggregation\\SINASC - Dtype Corrigido\\parquet\\DN2022.parquet')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE',
#        'ESTCIVMAE', 'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT',
#        'CODMUNRES', 'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC',
#        'HORANASC', 'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL',
#        'DTCADASTRO', 'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM',
#        'DIFDATA', 'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU',
#        'ESCMAE2010', 'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT',
#        'QTDPARTNOR', 'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC',
#        'TPMETESTIM', 'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART',
#        'STCESPARTO', 'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC',
#        'ESCMAEAGR1', 'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON',
#        'PARIDADE', 'KOTELCHUCK', 'CONTADOR'],
#       dtype='object')

# %%
# SIM['index'] = range(1, len(SIM) + 1)
# SIM.set_index('index', inplace = True)

df['index'] = range(2220000001, 2220000001 + len(df))
df.set_index('index', inplace=True)

# %%
df.index
# Out:
# Index([2220000001, 2220000002, 2220000003, 2220000004, 2220000005, 2220000006,
#        2220000007, 2220000008, 2220000009, 2220000010,
#        ...
#        2222856457, 2222856458, 2222856459, 2222856460, 2222856461, 2222856462,
#        2222856463, 2222856464, 2222856465, 2222856466],
#       dtype='int64', name='index', length=2856466)

# %%
if 'Unnamed: 0' in df.columns:
    df.drop('Unnamed: 0', axis=1, inplace=True)
    print('Unnamed removido')
else:
    print('Não removido')
# Out:
# Unnamed removido

# %%
df.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR'],
#       dtype='object')

# %%
df.to_parquet('D:\\_repositories\\Aggregation\\SINASC - Index adicionado\\DN2022.parquet')

# %%
df = pd.read_parquet('D:\\_repositories\\Aggregation\\SINASC - Index adicionado\\DN2022.parquet')

# %%
df.head(20)
# Out:
#             ORIGEM  CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# index
# 2220000001       1   5701929      120001        1        38          1
# 2220000002       1   5701929      120001        1        31          9
# 2220000003       1   5701929      120001        1        22          1
# 2220000004       1   5701929      120001        1        25          2
# 2220000005       1   5701929      120001        2        17          5
# 2220000006       1   5701929      120001        1        24          1
# 2220000007       1   2001020      120005        2        29          5
# 2220000008       1   2001020      120005        2        39          5
# 2220000009       1   2001020      120005        2        25          5
# 2220000010       1   2001020      120005        2        19          5
# 2220000011       1   2001020      120005        2        27          2
# 2220000012       1   2001020      120005        2        37          2
# ...

# %% [markdown]
# ---

# %%
df = pd.read_parquet('D:\\_repositories\\Aggregation\\SIM-2DtypeCorrigido\\parquet\\SIM2022.parquet')

# %%
len(df)
# Out:
# 58791

# %%
df.columns
# Out:
# Index(['ORIGEM', 'CODMUNCART', 'NUMREGCART', 'CODCART', 'DTREGCART',
#        'TIPOBITO', 'DTOBITO', 'HORAOBITO', 'NATURAL', 'CODMUNNATU', 'DTNASC',
#        'IDADE', 'SEXO', 'RACACOR', 'ESTCIV', 'ESC', 'ESC2010', 'SERIESCFAL',
#        'OCUP', 'CODMUNRES', 'LOCOCOR', 'CODESTAB', 'ESTABDESCR', 'CODMUNOCOR',
#        'IDADEMAE', 'ESCMAE', 'ESCMAE2010', 'SERIESCMAE', 'OCUPMAE',
#        'QTDFILVIVO', 'QTDFILMORT', 'GRAVIDEZ', 'SEMAGESTAC', 'GESTACAO',
#        'PARTO', 'OBITOPARTO', 'PESO', 'TPMORTEOCO', 'OBITOGRAV', 'OBITOPUERP',
#        'ASSISTMED', 'EXAME', 'CIRURGIA', 'NECROPSIA', 'LINHAA', 'LINHAB',
#        'LINHAC', 'LINHAD', 'LINHAII', 'CAUSABAS', 'CB_PRE', 'MEDICO',
#        'COMUNSVOIM', 'DTATESTADO', 'CIRCOBITO', 'ACIDTRAB', 'FONTE',
#        'NUMEROLOTE', 'TPPOS', 'DTINVESTIG', 'LINHAA_O', 'LINHAB_O', 'LINHAC_O',
#        'LINHAD_O', 'LINHAII_O', 'CAUSABAS_O', 'DTCADASTRO', 'ATESTANTE',
#        'STCODIFICA', 'CODIFICADO', 'VERSAOSIST', 'VERSAOSCB', 'FONTEINV',
# ...

# %%
x = 12200001
df['index'] = range(x, x + len(df))
df.set_index('index', inplace=True)

# %%
df.index
# Out:
# Index([12200001, 12200002, 12200003, 12200004, 12200005, 12200006, 12200007,
#        12200008, 12200009, 12200010,
#        ...
#        12258782, 12258783, 12258784, 12258785, 12258786, 12258787, 12258788,
#        12258789, 12258790, 12258791],
#       dtype='int64', name='index', length=58791)

# %%
if 'Unnamed: 0.1' in df.columns:
    df.drop('Unnamed: 0.1', axis=1, inplace=True)
    print('Unnamed removido')
else:
    print('Não removido')
# Out:
# Unnamed removido

# %%
df.to_parquet('D:\\_repositories\\Aggregation\\SIM-Index\\SIM2022.parquet')
